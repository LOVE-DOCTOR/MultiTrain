# %%
from MultiTrain import MultiRegressor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from MultiTrain import MultiRegressor
#
# File ~/mambaforge/envs/multitrain/lib/python3.10/site-packages/MultiTrain/__init__.py:1, in <module>
# ----> 1 from MultiTrain.classification.classification_models import MultiClassifier
#       2 from MultiTrain.regression.regression_models import MultiRegressor
#       3 from MultiTrain.__version__ import __version__
#
# File ~/mambaforge/envs/multitrain/lib/python3.10/site-packages/MultiTrain/classification/classification_models.py:3, in <module>
#       1 from collections import Counter
#       2 from operator import __setitem__
# ----> 3 import seaborn as sns
#       4 import plotly.express as px
#       5 # from hyperopt import tpe
#       6 # from hpsklearn import HyperoptEstimator, sklearn_ExtraTreesClassifier, random_forest
#
# ...
